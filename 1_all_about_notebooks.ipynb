# %%
print("hello welcome")

# %%
for i in range (10):
    print(i)

# %% [markdown]
# #all about magic commands in databrics notebook

# %% [markdown]
# #just a try

# %% [markdown]
# # magic commands used to design the notebook
# - %python -switch to python language in code cell
# - %sql - switch to sql
# - %md - to markdown
# - %sh - used to run linux commands
# - %fs - DBFS datbricks file system to intract with dbfs.
# - %scala - to run scala code
# - %pip - to install python packages
# - %run -call another notebook or python program

# %% [markdown]
# # All About Markdown
# ## welcome to **pyspark** world

# %% [markdown]
# `for i in 10`

# %% [markdown]
# [](test.url)

# %%
# %sh
pwd

# %%
# %sh
ls -ltr

# %%
# %sh
touch abc.txt
echo "welcome" >> abc.txt

# %%
# %sh
cat abc.txt
ls -ltr

# %%
# %run "/Workspace/Users/diviyacst@gmail.com/pythonpracticeworks/sample_python"

# %%
# %sql
select 'test'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.widgets.text("country",'')

# %%
country_name=dbutils.widgets.get("country")
print(country_name)
print(f"fetching {country_name} data from db")

# %%
dbutils.widgets.text("number","5")

# %%
int_range=int(dbutils.widgets.get("number"))
print(int_range)
for i in range(int_range):
    print(i)

# %%
dbutils.widgets.dropdown("gender","male",["male","female"])

# %%
gender=dbutils.widgets.get("gender")
print(gender)

# %%
dbutils.widgets.combobox("Country","India",["usa","china","india"])

# %%
country=dbutils.widgets.get("Country")
print(f"The selected country is {country}")
